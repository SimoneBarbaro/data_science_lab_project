# %%
from src.main import *

# %%
data = load_sample(frac=0.1, random_state=1, save=False)

# %%
ac = AgglomerativeClustering(n_clusters=8)

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
ac.fit(data)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='ward', memory=None, n_clusters=8,
#                         pooling_func='deprecated')

# %%
run_clustering(ac, tsne_dimred, perplexity=40, n_jobs=4, random_state=3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-9eec4cb2f882> in <module>
# ----> 1 run_clustering(ac, tsne_dimred, perplexity=40, n_jobs=4, random_state=3)
#
# ~\Documents\GitHub\data_science_lab_project\src\main.py in run_clustering(clusterer, embedding_fn, **embedding_args)
#      44 def run_clustering(clusterer, embedding_fn, **embedding_args):
#      45     data = load_sample(frac=0.1, random_state=1, save=False)
# ---> 46     labels = clusterer.fit(data).predict(data)
#      47     embedding = embedding_fn(data, **embedding_args)
#      48     plot_embedded_cluster(embedding, labels)
#
# AttributeError: 'AgglomerativeClustering' object has no attribute 'predict'

# %%
from sklearn.manifold import TSNE

# %%
embedded = TSNE().fit_transform(data)

# %%
f = np.random.rand(8)
plt.scatter(embedded[:, 0], embedded[:, 1], c=ac.labels_, label=ac.labels_)

# %%
import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering


def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_,
                                      counts]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)


iris = load_iris()
X = iris.data

# setting distance_threshold=0 ensures we compute the full tree.
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None)

model = model.fit(X)
plt.title('Hierarchical Clustering Dendrogram')
# plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode='level', p=3)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-7caad43c01e6> in <module>
#      38 plt.title('Hierarchical Clustering Dendrogram')
#      39 # plot the top three levels of the dendrogram
# ---> 40 plot_dendrogram(model, truncate_mode='level', p=3)
#      41 plt.xlabel("Number of points in node (or index of point if no parenthesis).")
#      42 plt.show()
#
# <ipython-input-30-7caad43c01e6> in plot_dendrogram(model, **kwargs)
#      22         counts[i] = current_count
#      23
# ---> 24     linkage_matrix = np.column_stack([model.children_, model.distances_,
#      25                                       counts]).astype(float)
#      26
#
# AttributeError: 'AgglomerativeClustering' object has no attribute 'distances_'
